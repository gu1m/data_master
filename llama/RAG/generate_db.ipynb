# %%
pip install langchain-core langchain-community langchain-text-splitters langchain-huggingface langchain-chroma
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "unstructured[all-docs]"
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 19.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------ --------------------------- 3.9/12.6 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------- ----------------------------- 10.5/38.6 MB 59.4 MB/s eta 0:00:01
#    ------------------- -------------------- 18.9/38.6 MB 56.7 MB/s eta 0:00:01
#    ------------------------ --------------- 23.6/38.6 MB 38.3 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 47.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 44.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
# ...

# %%
pip install regex
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.26.4
# Out:
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    --------- ------------------------------ 3.7/15.5 MB 18.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.7/15.5 MB 22.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.5 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 25.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\gguim\anaconda3\Lib\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\gguim\anaconda3\Lib\site-packages\~.mpy'.
#   You can safely remove it manually.
# ...

# %%
pip show torch
# Out:
# Name: torch
# Version: 2.5.1+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: C:\Users\gguim\anaconda3\envs\data_master\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: accelerate, bitsandbytes, effdet, sentence-transformers, timm, torchaudio, torchvision, unstructured_inference
# Note: you may need to restart the kernel to use updated packages.

# %%
from BuildVectorStore import PDFVectorStore

# %%
store = PDFVectorStore()

# %%
store.build_index()
# Out:
# 🔍 Processando documentos...
#   -> TXT: -ERM-COSO-Application-Techniques.txt
# 📦 Chunks gerados: 266
# 📦 Chunks únicos: 266
# 🧠 Criando embeddings...
# ✅ Vector store criado com sucesso!
