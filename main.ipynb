# %%
# !pip install -U langchain-chroma
# !pip install tqdm --upgrade
# !pip install --upgrade ipywidgets
# !pip install -U langchain-huggingface
# !pip install -q langchain_community
# !pip install -q sentence-transformers
# !pip install -q chromadb
# !pip install pandas
# !pip install torch==2.9.1
# !pip install "unstructured[all-docs]"

# %%
from llama.call_llama import call_llama
import warnings

warnings.filterwarnings("ignore")
# Out:
# C:\Users\gguim\Desktop\data_master\llama\call_llama.py:25: SyntaxWarning: invalid escape sequence '\l'
#   log_file: str = "logs_llama\llama_logs.jsonl"):

# %%
llm = call_llama(model_id = "meta-llama/Llama-3.2-3B-Instruct", device_map="cuda")
# Out:
# 🚀 Inicializando call_llama...
# 🔍 Carregando modelo de embeddings...
#  Carregando sistema de Re Rank...
# 🧠 Iniciando sistema de memória...
#
# ==========================
# 🧠 Sistema de Memória Iniciando
# 📁 DB Path: C:\Users\gguim\Desktop\data_master\llama\memory_support_db
# 📂 Pasta existe: True
# ==========================
#
# 🔄 Inicializando/Recriando cliente Chroma PERSISTENTE...
# 🟩 Coleção Chroma carregada: memory
# 📊 Memórias existentes: 16
# 📂 Arquivos no DB: ['chroma.sqlite3', 'f68a2ed3-6bd5-4dae-987a-d8136e96d20c']
# 📚 Iniciando sistema de RAG...
# ⚙️ Carregando modelo Llama local (pode levar alguns segundos)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ call_llama inicializado com sucesso!

# %%
resposta = llm.invoke(
    system = "Você é um especilista em Riscos Operacionais e Controles Internos do Banco Santander",
    user = "O que é Enterprise Risk Management (ERM) segundo o COSO? Me traga o trecho da onde você retirou sua resposta com base no BLOCO de RAG"
)

# %%
print(resposta)

# %%
resposta = llm.invoke(
    system = "Você é um especilista em Riscos Operacionais e Controles Internos do Banco Santander",
    user = "Segundo o glossário do COBIT 5, qual a definição para o termo (Risco)?"
)

# %%
print(resposta)

# %%
resposta = llm.invoke(
    system = "Você é um especilista em Riscos Operacionais e Controles Internos do Banco Santander",
    user = "Qual a finalidade da (Tabela RACI) dentro da estrutura organizacional, segundo o COBIT 5?"
)

# %%
print(resposta)

# %%
resposta = llm.invoke(
    system = "Você é um especilista em Riscos Operacionais e Controles Internos do Banco Santander",
    user = "O que é Enterprise Risk Management (ERM) segundo o COSO?"
)

# %%
print(resposta)
